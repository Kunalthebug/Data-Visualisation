# %%
import pandas as pd
import matplotlib.pyplot as plt
from numpy.random import randint as ri
from numpy.random import randn
import numpy as np
import seaborn as sns
from jupyterthemes import jtplot
jtplot.style(theme='onedork')

# %%
mat=np.array(ri(10,100,15).reshape(3,5))
mat
# Out:
# array([[87, 68, 68, 55, 64],
#        [16, 35, 65, 22, 49],
#        [11, 17, 21, 29, 19]])

# %%
mat>40
# Out:
# array([[ True,  True,  True,  True,  True],
#        [False, False,  True, False,  True],
#        [False, False, False, False, False]])

# %%
mat[mat>50]#fetch all data which is greater than 50
# Out:
# array([87, 68, 68, 55, 64, 65])

# %%
#SLICING
mat=np.array([[11,12,13],[21,22,23],[31,32,33]])
mat
# Out:
# array([[11, 12, 13],
#        [21, 22, 23],
#        [31, 32, 33]])

# %%
mat_slice=mat[:2,:2]
mat_slice
# Out:
# array([[11, 12],
#        [21, 22]])

# %%
print(mat_slice)
# Out:
# [[11 12]
#  [21 22]]

# %%
mat_slice[0][0]=10

# %%
mat_slice
# Out:
# array([[10, 12],
#        [21, 22]])

# %%
mat1=np.array(ri(1,10,9)).reshape(3,3)
mat2=np.array(ri(1,10,9)).reshape(3,3)
mat1,mat2
# Out:
# (array([[1, 2, 1],
#         [6, 3, 2],
#         [6, 3, 6]]), array([[2, 3, 5],
#         [4, 6, 8],
#         [6, 9, 6]]))

# %%
mat1*mat2
# Out:
# array([[ 2,  6,  5],
#        [24, 18, 16],
#        [36, 27, 36]])

# %%
#matrix multiplication is done using '@' symbol
print(mat1@mat2)
# Out:
# [[16 24 27]
#  [36 54 66]
#  [60 90 90]]

# %%
#Broadcassting
start=np.zeros((4,4))
start+=100
start
# Out:
# array([[100., 100., 100., 100.],
#        [100., 100., 100., 100.],
#        [100., 100., 100., 100.],
#        [100., 100., 100., 100.]])

# %%
df=pd.DataFrame(randn(1000),index=pd.date_range('2019-06-07',periods=1000),columns=['value'])
ts=pd.Series(randn(1000),index=pd.date_range('2019-06-07',periods=1000))
df.head()
# Out:
#                value
# 2019-06-07  1.111551
# 2019-06-08 -0.927401
# 2019-06-09  1.213457
# 2019-06-10 -1.298106
# 2019-06-11 -1.555787

# %%
df['value']=df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07  1.111551
# 2019-06-08  1.295702
# 2019-06-09  2.693309
# 2019-06-10  2.792810
# 2019-06-11  1.336525

# %%
ts
# Out:
# 2019-06-07   -0.973039
# 2019-06-08    0.877925
# 2019-06-09   -0.633294
# 2019-06-10   -0.795213
# 2019-06-11    0.586891
#                 ...
# 2022-02-26    0.679075
# 2022-02-27   -0.432163
# 2022-02-28   -0.536381
# 2022-03-01   -0.550811
# 2022-03-02    1.631734
# Freq: D, Length: 1000, dtype: float64

# %%
ts=ts.cumsum()

# %%
type(df),type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(25,10))

# %%
plt.figure(figsize=(25,10))
plt.plot(df)

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ax=iris.plot(figsize=(25,5),title="IRIS DATASET")
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
ts.plot(kind='bar')

# %%
df=iris.drop(['species'],axis=1)

# %%
a=df.iloc[0]

# %%
a.plot(kind='bar')

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df=pd.DataFrame(randn(10,4),columns=['a','b','c','d'])

# %%
df
# Out:
#           a         b         c         d
# 0 -0.330078 -0.387054 -0.645846 -0.986398
# 1  0.946013  0.573681  0.159868  0.086246
# 2 -0.019533  0.449773  0.390161 -0.063425
# 3  1.606676  2.013440  0.990602 -1.565262
# 4 -2.028679  1.226548  0.046213 -0.607945
# 5 -1.465300 -0.051619 -0.133022  0.220015
# 6 -0.209542  1.076069  0.099802 -0.280874
# 7  0.246686 -1.197768  0.551621  0.923560
# 8 -1.175694  0.733064  2.095441 -0.234308
# 9 -0.437058  0.575237  0.178102 -0.733436

# %%
df.plot.bar()

# %%
df.plot(kind='bar')

# %%
df.plot(kind='barh')

# %%
df.plot.hist()

# %%
iris.plot(kind='hist')

# %%
iris.plot(kind='hist',bins=100)

# %%
iris['sepal_width'].diff().plot(kind='hist',bins=60)

# %%
df=iris.drop(['species'],axis=1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CC0DC6BA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CC0FB5B7F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CC0C827400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CC0E131B38>]],
#       dtype=object)

# %%
df.
